# %%
import pandas as pd

# %%
df = pd.read_csv('C:\Workspace\SEfactory\Week1\kc_house_data.csv')

# %%
df.shape
# Out:
# (21613, 21)

# %%
# KC house is a dataset documenting 21,613 instances ofvaluations of houses in King County, relative to 19 different specifications. 
#It starts with the id followed by the date of valuation. 
#The different specifications are: The Number of Bedrooms , The Number of Bathrooms, Total Square Footage of Living Space,
# Total Lot Square Footage, Number of Floors, Whether the Property Is a Waterfront or Not( 1 for Yes, 0 for No), How Many Views It Has, 
#Condition of the House Ranked on a scale of 1 to 5, The Grading of the House, Square footage of Above, Square Footage of The Basement,
# Year the House Was Built, Year The House Was Renovated, Area Zipcode, Latitude, Logitude, Square footage of Living15,and Square footage of Lot15)
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
# The Number of Bedrooms:
#They Range from: 0 - 33 bedrooms
df.bedrooms.min()
# Out:
# 0

# %%
df.bedrooms.max()
# Out:
# 33

# %%
# The Number of Bathrooms:
#They Range from: 0.0 - 8.0 Baths
df.bathrooms.min()
# Out:
# 0.0

# %%
df.bathrooms.max()
# Out:
# 8.0

# %%
df.price.max()
# Out:
# 7700000.0

# %%
df.price.min()
# Out:
# 75000.0

# %%
df.zipcode.value_counts()
# Out:
# zipcode
# 98103    602
# 98038    590
# 98115    583
# 98052    574
# 98117    553
#         ...
# 98102    105
# 98010    100
# 98024     81
# 98148     57
# 98039     50
# Name: count, Length: 70, dtype: int64

# %%
df[df.price==7700000]
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 7252  6762700020  20141013T000000  7700000.0         6        8.0
#
#       sqft_living  sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 7252        12050     27600     2.5           0     3  ...     13        8570
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 7252           3480      1910          1987    98102  47.6298 -122.323
#
#       sqft_living15  sqft_lot15
# 7252           3940        8800
#
# [1 rows x 21 columns]

# %%
df.sqft_living.max()
# Out:
# 13540

# %%
df[df.sqft_living==13540]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 12777  1225069038  20140505T000000  2280000.0         7        8.0
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 12777        13540    307752     3.0           0     4  ...     12
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 12777        9410           4130      1999             0    98053  47.6675
#
#           long  sqft_living15  sqft_lot15
# 12777 -121.986           4850      217800
#
# [1 rows x 21 columns]

# %%
#if we are looking on the upper price ranges , house id 1225069038 looks to be a far better deal then house id 6762700020 that happens to be the priciest house costing 7,700,000.0
# Both houses are in close location to one another, house # 7252 is located at lat 47.6298 long -122.323 and house #12777 at lat 47.6675 long -121.986
# with house # 12777 being much less expensive, has a much bigger square footage, more bedrooms, and it's a more recent build.

# %%
df.nsmallest(10,'price')
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 1149   3421079032  20150217T000000  75000.0         1       0.00          670
# 15293    40000362  20140506T000000  78000.0         2       1.00          780
# 465    8658300340  20140523T000000  80000.0         1       0.75          430
# 16198  3028200080  20150324T000000  81000.0         2       1.00          730
# 8274   3883800011  20141105T000000  82000.0         3       1.00          860
# 2141   1623049041  20140508T000000  82500.0         2       1.00          520
# 18468  7999600180  20140529T000000  83000.0         2       1.00          900
# 3767   1523049188  20150430T000000  84000.0         2       1.00          700
# 10253  2422049104  20140915T000000  85000.0         2       1.00          830
# 16714  1322049150  20150305T000000  85000.0         2       1.00          910
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
df.sqft_living.mean()
# Out:
# 2079.8997362698374

# %%
df.sqft_living.median()
# Out:
# 1910.0

# %%
#The mean is close to the median meaning that the distribution is not skewed too much.

# %%
df[df.sqft_living==1910]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 163    3574800520  20140620T000000  441000.0         3       2.75
# 198    2824079053  20150113T000000  440000.0         3       2.50
# 356    5416510830  20140806T000000  300000.0         4       2.50
# 736    3626039299  20150224T000000  588000.0         3       1.00
# 777    3814400125  20141016T000000  493000.0         4       2.00
# ...           ...              ...       ...       ...        ...
# 19834  6817750140  20140708T000000  293000.0         3       2.25
# 20272  3630130010  20140714T000000  650000.0         3       2.50
# 20374  8138870470  20140707T000000  494815.0         3       2.50
# 21177  3630130130  20141112T000000  663000.0         3       2.50
# 21492  7283900306  20150417T000000  400000.0         3       2.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 163           1910      7280     1.0           0     0  ...      7
# ...

# %%
ld =df[df.sqft_living==1910]
display(ld)
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 163    3574800520  20140620T000000  441000.0         3       2.75
# 198    2824079053  20150113T000000  440000.0         3       2.50
# 356    5416510830  20140806T000000  300000.0         4       2.50
# 736    3626039299  20150224T000000  588000.0         3       1.00
# 777    3814400125  20141016T000000  493000.0         4       2.00
# ...           ...              ...       ...       ...        ...
# 19834  6817750140  20140708T000000  293000.0         3       2.25
# 20272  3630130010  20140714T000000  650000.0         3       2.50
# 20374  8138870470  20140707T000000  494815.0         3       2.50
# 21177  3630130130  20141112T000000  663000.0         3       2.50
# 21492  7283900306  20150417T000000  400000.0         3       2.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 163           1910      7280     1.0           0     0  ...      7
# ...

# %%
ld.head()
# Out:
#              id             date     price  bedrooms  bathrooms  sqft_living  \
# 163  3574800520  20140620T000000  441000.0         3       2.75         1910
# 198  2824079053  20150113T000000  440000.0         3       2.50         1910
# 356  5416510830  20140806T000000  300000.0         4       2.50         1910
# 736  3626039299  20150224T000000  588000.0         3       1.00         1910
# 777  3814400125  20141016T000000  493000.0         4       2.00         1910
#
#      sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 163      7280     1.0           0     0  ...      7        1160
# 198     66211     2.0           0     0  ...      7        1910
# 356      4862     2.0           0     0  ...      7        1910
# 736      8167     1.0           0     0  ...      8        1270
# 777      2874     1.0           0     0  ...      7        1060
#
#      sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
ld.price.mean()
# Out:
# 477944.48148148146

# %%
ld.price.median()
# Out:
# 460000.0

# %%
ld.price.min()
# Out:
# 175000.0

# %%
ld[ld.price==175000]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 17133  6143000020  20141027T000000  175000.0         3       1.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 17133         1910     17003     1.5           0     0  ...      8
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 17133        1910              0      1963             0    98001  47.3095
#
#           long  sqft_living15  sqft_lot15
# 17133 -122.283           1820       14806
#
# [1 rows x 21 columns]

# %%
ld[ld.price==460000]
# Out:
#               id             date     price  bedrooms  bathrooms  sqft_living  \
# 7593  2207200405  20140716T000000  460000.0         5        2.0         1910
#
#       sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 7593     12264     1.0           0     0  ...      7        1010
#
#       sqft_basement  yr_built  yr_renovated  zipcode     lat     long  \
# 7593            900      1963             0    98007  47.601 -122.134
#
#       sqft_living15  sqft_lot15
# 7593           1700        9179
#
# [1 rows x 21 columns]

# %%
ld.bedrooms.mean()
# Out:
# 3.5185185185185186

# %%
ld.bedrooms.max()
# Out:
# 5

# %%
ld.bathrooms.mean()
# Out:
# 2.123456790123457

# %%
ld.sqft_lot.mean()
# Out:
# 11139.962962962964

# %%
#for around the average living space and average bedrooms and bathrooms, house id 6143000020 seems the most reasonably priced
